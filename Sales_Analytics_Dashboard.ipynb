# %% [markdown]
# # **Data Cleaning and Preparation for Ensuring Data Integrity**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Step 1: Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Step 2: Upload Dataset

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5d6c42cf-e620-4320-85ef-f2a9f156405c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d6c42cf-e620-4320-85ef-f2a9f156405c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Step 3: Read Excel File

# %%
df = pd.read_excel("Dataset for Data Analytics.xlsx")

df.head()
# Out:
#      OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004 2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %% [markdown]
# # Step 4: Check Dataset Information

# %%
print(df.shape)
# Out:
# (1200, 14)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   object
#  1   Date             1200 non-null   datetime64[ns]
#  2   CustomerID       1200 non-null   object
#  3   Product          1200 non-null   object
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   object
#  7   PaymentMethod    1200 non-null   object
#  8   OrderStatus      1200 non-null   object
#  9   TrackingNumber   1200 non-null   object
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       891 non-null    object
#  12  ReferralSource   1200 non-null   object
#  13  TotalPrice       1200 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(9)
# memory usage: 131.4+ KB
# None

# %%
df.describe()
# Out:
#                       Date     Quantity    UnitPrice  ItemsInCart   TotalPrice
# count                 1200  1200.000000  1200.000000  1200.000000  1200.000000
# mean   2024-03-22 16:58:48     2.945833   356.412750     5.485000  1053.968300
# min    2023-01-01 00:00:00     1.000000    11.390000     1.000000    11.390000
# 25%    2023-08-03 18:00:00     2.000000   186.062500     4.000000   410.520000
# 50%    2024-03-23 00:00:00     3.000000   364.210000     5.000000   823.615000
# 75%    2024-11-08 12:00:00     4.000000   521.570000     7.000000  1578.475000
# max    2025-06-30 00:00:00     5.000000   699.930000    10.000000  3456.400000
# std                    NaN     1.407557   197.177146     2.281983   819.856558

# %% [markdown]
# # Step 5: Find Missing Values

# %%
df.isnull().sum()
# Out:
# OrderID              0
# Date                 0
# CustomerID           0
# Product              0
# Quantity             0
# UnitPrice            0
# ShippingAddress      0
# PaymentMethod        0
# OrderStatus          0
# TrackingNumber       0
# ItemsInCart          0
# CouponCode         309
# ReferralSource       0
# TotalPrice           0
# dtype: int64

# %%
missing=(df.isnull().sum()/len(df))*100

print(missing)
# Out:
# OrderID             0.00
# Date                0.00
# CustomerID          0.00
# Product             0.00
# Quantity            0.00
# UnitPrice           0.00
# ShippingAddress     0.00
# PaymentMethod       0.00
# OrderStatus         0.00
# TrackingNumber      0.00
# ItemsInCart         0.00
# CouponCode         25.75
# ReferralSource      0.00
# TotalPrice          0.00
# dtype: float64

# %% [markdown]
# # Step 6: Handle Missing Values

# %%
num_cols=df.select_dtypes(include=np.number)

for col in num_cols:
    df[col]=df[col].fillna(df[col].median())

# %%
cat_cols=df.select_dtypes(include='object')

for col in cat_cols:
    df[col]=df[col].fillna(df[col].mode()[0])

# %% [markdown]
# # Step 7: Find Duplicate Records

# %%
duplicates=df.duplicated().sum()

print("Duplicates:",duplicates)
# Out:
# Duplicates: 0

# %% [markdown]
# # Step 8: Remove Duplicates

# %%
df=df.drop_duplicates()

print(df.shape)
# Out:
# (1200, 14)

# %% [markdown]
# # Step 9: Check Duplicate IDs

# %%
duplicate_ids = df["OrderID"].duplicated().sum()

print(duplicate_ids)
# Out:
# 0

# %% [markdown]
# # Step 7: Check Data Types

# %%
print(df.dtypes)
# Out:
# OrderID                    object
# Date               datetime64[ns]
# CustomerID                 object
# Product                    object
# Quantity                    int64
# UnitPrice                 float64
# ShippingAddress            object
# PaymentMethod              object
# OrderStatus                object
# TrackingNumber             object
# ItemsInCart                 int64
# CouponCode                 object
# ReferralSource             object
# TotalPrice                float64
# dtype: object

# %%
df["Date"] = pd.to_datetime(df["Date"])

print(df["Date"].head())
# Out:
# 0   2023-01-04
# 1   2024-08-23
# 2   2024-02-27
# 3   2023-10-15
# 4   2025-05-08
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# # Step 8: Remove Extra Spaces (Text Cleaning)

# %%
text_columns = df.select_dtypes(include="object").columns

for col in text_columns:
    df[col] = df[col].str.strip()

print("Spaces Removed")
# Out:
# Spaces Removed

# %% [markdown]
# # Step 9: Standardize Text Format

# %%
df["Date"] = pd.to_datetime(df["Date"], errors="coerce", dayfirst=True)

# %%
df["Product"] = df["Product"].str.title()

df["OrderStatus"] = df["OrderStatus"].str.title()

# %%
print(df[["Product","OrderStatus"]].head())
# Out:
#    Product OrderStatus
# 0  Monitor     Shipped
# 1    Phone     Shipped
# 2   Tablet   Cancelled
# 3    Chair    Returned
# 4  Printer   Delivered

# %% [markdown]
# # Step 10: Verify No Duplicate Order IDs

# %%
duplicate_ids = df["OrderID"].duplicated().sum()

print("Duplicate Order IDs:", duplicate_ids)
# Out:
# Duplicate Order IDs: 0

# %% [markdown]
# # Step 11: Verify Date Format

# %%
print(df["Date"].dtype)
# Out:
# datetime64[ns]

# %%
print(df["Date"].head())
print(df["Date"].dtype)
# Out:
# 0   2023-01-04
# 1   2024-08-23
# 2   2024-02-27
# 3   2023-10-15
# 4   2025-05-08
# Name: Date, dtype: datetime64[ns]
# datetime64[ns]

# %% [markdown]
# # Step 12: Save Cleaned Dataset

# %%
df["Date"] = pd.to_datetime(df["Date"]).dt.strftime("%d-%m-%Y")

# %%
df.to_excel("Cleaned_Dataset.xlsx",index=False)

print("Dataset Saved Successfully")
# Out:
# Dataset Saved Successfully

# %%
files.download("Cleaned_Dataset.xlsx")

# %% [markdown]
# # Step 13: Create Change Log (Important for Submission)

# %%
change_log = {

"Missing Values":"Filled CouponCode missing values",

"Duplicates":"Removed duplicate rows",

"Formatting":"Standardized date and text formats"

}

print(change_log)
# Out:
# {'Missing Values': 'Filled CouponCode missing values', 'Duplicates': 'Removed duplicate rows', 'Formatting': 'Standardized date and text formats'}
